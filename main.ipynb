# %% [markdown]
# ### 1. Ask About Trending News

# %%
import csv

subject = [
  "នៅទីនេះ",
  "ក្នុងនេះ",
  "នេះ",
  "កន្លែងនេះ",
  "កន្លែងនឹង",
  "ទីនេះ",
  "នៅនេះ",
  "នៅឯនេះ",
  "នៅនឹង",
  "នៅឯCADT",
  "នៅCADT",
  "នៅឯសុីអេដីធី",
  "នៅសុីអេដីធី",
  "នៅឯNIPTICT",
  "នៅណិពទិច",
  "Cambodia Academy of Digital Technology",
  'បណ្ឌិត្យសភាបច្ចេកវិទ្យាឌីជីថលកម្ពុជា',
  "វិទ្យាស្ថានបច្ចេកវិទ្យាឌីជីថល",
]

verb =[
    "មាន"
]
adjective = [
     "ប្លែកៗ",
     "រំភើប",
     "ថ្មី",
     "ថ្មីៗ",
     "សម្រាប់សិស្សថ្មី",
     "សម្រាប់សិស្ស",
     "សម្រាប់បុគ្គលិកថ្មី",
     "សម្រាប់បុគ្គលិក",
     "សម្រាប់អ្នកទស្សនៈកិច្ច",
     "សម្រាប់អ្នកមកមើល",
]

object = [
    "ព័ត៌មាន",
    "រឿង",
    "ហេតុការណ៍",
]

question = [
    "អ្វី",
    "អ្វីខ្លះ",
    "អត់",
]

preposition =[
    "នៅ",
]
  
def write_to_csv():
  # open the file in the write mode
  f = open('1.AskAboutTrendingNews.csv', 'w',encoding="utf-8")

  # create the csv writer
  writer = csv.writer(f)

  # write a generated sentences to the csv file
  for obj in object:
    for v in verb:
     for adj in adjective:
      for q in question:
        for s in subject: 
          sentence1 = "តើ" + v +obj + adj + q + s + "?"
          # sentence4 = "ចង់សួរថាតើ" + v +obj + adj + q + s + "?"
          # sentence6 = "ចង់សួរអូនឯងថាតើ" + v +obj + adj + q + s + "?"
          # sentence8 = "ចង់សួរអាក្អូនឯងថាតើ" + v +obj + adj + q + s + "?"
          # sentence9 = "ហេសួរមួយ" + v +obj + adj + q + s + "?"
          # sentence10 = "ហេសួរមួយថា" + v +obj + adj + q + s + "?"
          writer.writerow([sentence1])

  # close the file
  f.close()

write_to_csv()

# %% [markdown]
# ### 2. Curiculum In Each Major

# %%
import csv

subject = [
  "Information Technology",
  "អុីហ្វមេសុិន តិចណូឡូជី",
  "ព​ត៌​មាន​វិទ្យា",
  "អាយធី",
  "IT",

  "computer science ",
  "វិទ្យាសាស្រ្តកុំព្យូទ័រ",
  "កុំព្យូទ័រសាយអេន",

  "e-commerce"
  "ពាណិជ្ជកម្មអេឡិចត្រូនិច",
  "អុីខមមើស",

  "Telecoms and Networking",
  "Telecoms",
  "Networking",
  "Network",
  "ទូរគមនាគមន៍និងបណ្តាញ",
  "ទូរគមនាគមន៍",
  "បណ្តាញ",
  "តេឡេខម",
  "ណេតវើក",
  "ណេតវើកកីង",
]

verb =[
    "មាន"
]
adjective = [
     "ថ្មី",
     "ថ្មីៗ",
]
# តើវិទ្យាសាស្រ្តកុំព្យូទ័រមានកម្មវិធីសិក្សាដូចមេ្តច?
object = [
    "កម្មវិធីសិក្សា",
    "កម្មវិធីរៀន",
    "រៀន",
]

question = [
    "ដូចមេ្តចខ្លះ",
    "អ្វីខ្លះ",
    "អីខ្លះ",
    "ម៉េចខ្លះ",
    "ស្អីខ្លះ",
    "ស្អីខ្លះហា",
    "ស្អីគេខ្លះ",
]

preposition =[
    "ខាង",
    "នៅក្នុងជំនាញ",
    "នៅខាង",
    "នៅខាងជំនាញ",
]
  
def write_to_csv():
  # open the file in the write mode
  f = open('2.CuriculumInEachMajor.csv', 'w',encoding="utf-8")

  # create the csv writer
  writer = csv.writer(f)

  # write a generated sentences to the csv file
  for obj in object:
    for v in verb:
      for q in question:
        for s in subject: 
          for prep in preposition:
            sentence3 = "តើ" + v +obj + q + prep + s + "?"          
            writer.writerow([sentence3])
            
  for obj in object:
     for v in verb:
      for q in question:
        for s in subject: 
                sentence4 = "តើ" + s + v + obj + q + "?"
                writer.writerow([sentence4])
    
  f.close()

write_to_csv()

# %% [markdown]
# ### 3.AskBuildingInformationInCADT

# %%
import csv

subject = [
    "Inovation Center",
    "អុីននូវេសុិន​សេនធឺ",
]

subject1 = [
    "CADT",
    "ខេត",
    "នៅឯCADT",
    "នៅCADT",
    "នៅឯសុីអេដីធី",
    "នៅសុីអេដីធី",
    "នៅឯNIPTICT",
    "នៅណិពទិច",
    "វិទ្យាស្ថានបច្ចេកវិទ្យាឌីជីថល",
    "បណ្ឌិត្យសភាបច្ចេកវិទ្យាឌីជីថលកម្ពុជា"
]


verb = [
    "បង្កើតឡើងសម្រាប់ធ្វើ",
    "បង្កើតឡើងដើម្បី",
    "សាងសងឡើងសម្រាប់ធ្វើ",
    "សាងសងឡើងដើម្បី",
]
adjective = [
    "ថ្មី",
    "ថ្មីៗ",
]

object = [
    "អគារ",
]
question = [
    "អ្វីខ្លះ",
    "អ្វី",
]
question_amount = [
    "មានប៉ុន្មាន",
    "មានសរុបប៉ុន្មាន",
    "មានម៉ាន",
]

preposition = [
    "នៅ",
]


def write_to_csv():
    # open the file in the write mode
    f = open('3.AskBuildingInformationInCADT.csv', 'w', encoding="utf-8")

    # create the csv writer
    writer = csv.writer(f)

    # write a generated sentences to the csv file
    for obj in object:
        for v in verb:
            for adj in adjective:
                for q in question:
                    for s in subject:
                        for prep in preposition:
                            for q_a in question_amount:
                                for s1 in subject1:
                                    # ​ តើអគារនៅcadtមានប៉ុន្មាន
                                    # ​ តើអគារ Inovation center បង្កើតឡើងសម្រាប់ធ្វើអី្វ?
                                    # ​ តើអគារ IDT បង្កើតឡើងសម្រាប់ធ្វើអី្វ?
                                    sentence1 = obj + s1 + q_a + "?"
                                    sentence2 = obj + prep + s + v + q + "?"
                                    writer.writerow([sentence1])
                                    writer.writerow([sentence2])
    f.close()


write_to_csv()

# %% [markdown]
# ### 4. FindToilet

# %%
import csv

subject = []

verb =[
    "មាន"
]
adjective = [
     "ថ្មី",
     "ថ្មីៗ",
]

object = [
     "បង្គន់",
     "កន្លែងបន្ទោបង",
     "កន្លែងរំដោះទុក្ខសត្វ",
     "បន្ទោបង",
     "បន្ទប់ទឹក",
     "កន្លែងនោម",
     "កន្លែងឈឺនោម",
     "កន្លែងឈឺអាចម៍",
     "កន្លែងបត់ជើង",
     "កន្លែងបត់ជើងតូច",
     "កន្លែងបត់ជើងធំ",
     "កន្លែងបត់ជើងធំ",
     "កន្លែងជុះអាចម៍",
     "កន្លែងជុះនោម",
]

question = [
    "ដូចមេ្តចខ្លះ",
    "អ្វីខ្លះ",
    "អីខ្លះ",
    "មេ៉ចខ្លះ",
    "ស្អីខ្លះ",
    "ស្អីខ្លះហា",
    "ស្អីគេខ្លះ",
]
question_amount = [
    "ប៉ុន្មាន",
    "ម៉ាន",
]
question_place = [
    "នៅឯណា",
    "នៅឯណាខ្លះ",
    "នៅកន្លែងណា",
    "នៅកន្លែងណាខ្លះ",
]

question_place1 = [
    "នៅឯណាខ្លះ",
    "នៅកន្លែងណាខ្លះ",
]

preposition =[
    "ខាង",
    "នៅក្នុងជំនាញ",
    "នៅខាង",
    "នៅខាងជំនាញ",
]
  
def write_to_csv():
  # open the file in the write mode
  f = open('4.FindToilet.csv', 'w',encoding="utf-8")

  # create the csv writer
  writer = csv.writer(f)

  # write a generated sentences to the csv file
  for obj in object:
    for v in verb:
      for q in question_place:    
        for q1 in question_place1:    
            sentence1 =  obj + v + q + "?"    
            sentence5 =  q+ v + obj + "?"          
            # sentence2 =  obj + v + q1 + "?"            
            # sentence3 =  obj + q1 + "?"            
            # sentence4 =  obj + q + "?"            
                      
            # sentence2 =  s + v + obj + q + "?"
            # sentence3 = "តើ" + v +obj + q + prep + s + "?"
            # sentence4 = "តើ" + s + v + obj + q + "?"
            # sentence5 = "ចង់សួរថាតើ" + v +obj + q + prep + s + "?"
            # sentence6 = "ចង់សួរថាតើ" + s + v + obj + q + "?"
            # sentence7 = "ចង់សួរអូនឯងថាតើ" + v +obj + q + prep + s + "?"
            # sentence8 = "ចង់សួរអូនឯងថាតើ" + s + v + obj + q + "?"
            # sentence9 = "ចង់សួរអាក្អូនឯងថាតើ" + v +obj + q + prep + s + "?"
            # sentence10 = "ចង់សួរអាក្អូនឯងថាតើ" + s + v + obj + q + "?"
            # sentence11 = "ហេសួរមួយ" + v +obj + q + prep + s + "?"
            # sentence12 = "ហេសួរមួយ"  + s + v + obj + q + "?"
            # sentence13 = "ហេសួរមួយថា" + v +obj + q + prep + s + "?"
            # sentence14 = "ហេសួរមួយថា" + s + v + obj + q + "?"
            writer.writerow([sentence1])
            # writer.writerow([sentence2])
            # writer.writerow([sentence3])
            # writer.writerow([sentence4])
            writer.writerow([sentence5])
            # writer.writerow([sentence3])
            # writer.writerow([sentence4])
            # writer.writerow([sentence5])
            # writer.writerow([sentence6])
            # writer.writerow([sentence7])
            # writer.writerow([sentence8])
            # writer.writerow([sentence9])
            # writer.writerow([sentence10])
            # writer.writerow([sentence11])
            # writer.writerow([sentence12])
            # writer.writerow([sentence13])
            # writer.writerow([sentence14])
  f.close()

write_to_csv()

# %% [markdown]
# ### 5. IsToiletExist

# %%
import csv
# តើមាន​បង្គន់នៅនេះអត់
subject = [
  "នៅទីនេះ",
  "នៅជាន់នេះ",
  "នៅជាន់នឹង",
  "នៅនេះ",
  "នៅឯនេះ",
  "នៅនឹង",
  "នៅឯCADT",
  "នៅCADT",
  "នៅឯសុីអេដីធី",
  "នៅសុីអេដីធី",
  "នៅឯNIPTICT",
  "នៅណិពទិច",
    "នៅណិពទិច",
    "វិទ្យាស្ថានបច្ចេកវិទ្យាឌីជីថល",
    "បណ្ឌិត្យសភាបច្ចេកវិទ្យាឌីជីថលកម្ពុជា"
]

verb =[
    "មាន"
]
adjective = [
     "ថ្មី",
     "ថ្មីៗ",
]

object = [
     "បង្គន់",
     "កន្លែងបន្ទោបង",
     "កន្លែងរំដោះទុក្ខសត្វ",
     "បន្ទោបង",
     "បន្ទប់ទឹក",
     "កន្លែងនោម",
     "កន្លែងឈឺនោម",
     "កន្លែងបត់ជើង",
     "កន្លែងបត់ជើងតូច",
     "កន្លែងបត់ជើងធំ",
     "កន្លែងបត់ជើងធំ",
     "កន្លែងជុះអាចម៍",
]

question = [
    "អត់",
    "ដែរឫទេ",
    "ដែរអត់"
]
question_amount = [
    "ប៉ុន្មាន",
    "ម៉ាន",
]
question_place = [
    "នៅឯណា",
    "នៅឯណាខ្លះ",
    "នៅកន្លែងណា",
    "នៅកន្លែងណាខ្លះ",
]

question_place1 = [
    "នៅឯណាខ្លះ",
    "នៅកន្លែងណាខ្លះ",
]

preposition =[
    "ខាង",
    "នៅក្នុងជំនាញ",
    "នៅខាង",
    "នៅខាងជំនាញ",
]
  
def write_to_csv():
  # open the file in the write mode
  f = open('5.IsToiletExist.csv', 'w',encoding="utf-8")

  # create the csv writer
  writer = csv.writer(f)

  # write a generated sentences to the csv file
  for obj in object:
    for v in verb:
      for q in question:   
        for s in subject:
            sentence1 =  v + obj + s + "?"                      
            sentence2 =  s + v + obj + q + "?"                      
            writer.writerow([sentence1])
            writer.writerow([sentence2])
  f.close()

write_to_csv()

# %% [markdown]
# ### 6. FindRoomInfo

# %%
import csv

subject = []

verb =[
    "មាន"
]
adjective = [
     "ថ្មី",
     "ថ្មីៗ",
]

object = [
     "",
     "កន្លែងបន្ទោបង",
     "កន្លែងរំដោះទុក្ខសត្វ",
     "បន្ទោបង",
     "បន្ទប់ទឹក",
     "កន្លែងនោម",
     "កន្លែងឈឺនោម",
     "កន្លែងឈឺអាចម៍",
     "កន្លែងបត់ជើង",
     "កន្លែងបត់ជើងតូច",
     "កន្លែងបត់ជើងធំ",
     "កន្លែងបត់ជើងធំ",
     "កន្លែងជុះអាចម៍",
     "កន្លែងជុះនោម",
]

question = [
    "ដូចមេ្តចខ្លះ",
    "អ្វីខ្លះ",
    "អីខ្លះ",
    "មេ៉ចខ្លះ",
    "ស្អីខ្លះ",
    "ស្អីខ្លះហា",
    "ស្អីគេខ្លះ",
]
question_amount = [
    "ប៉ុន្មាន",
    "ម៉ាន",
]
question_place = [
    "នៅឯណា",
    "នៅឯណាខ្លះ",
    "នៅកន្លែងណា",
    "នៅកន្លែងណាខ្លះ",
]

question_place1 = [
    "នៅឯណាខ្លះ",
    "នៅកន្លែងណាខ្លះ",
]

preposition =[
    "ខាង",
    "នៅក្នុងជំនាញ",
    "នៅខាង",
    "នៅខាងជំនាញ",
]
  
def write_to_csv():
  # open the file in the write mode
  f = open('4.FindToilet.csv', 'w',encoding="utf-8")

  # create the csv writer
  writer = csv.writer(f)

  # write a generated sentences to the csv file
  for obj in object:
    for v in verb:
      for q in question_place:    
        for q1 in question_place1:    
            sentence1 =  obj + v + q + "?"    
            sentence5 =  q+ v + obj + "?"          
            # sentence2 =  obj + v + q1 + "?"            
            # sentence3 =  obj + q1 + "?"            
            # sentence4 =  obj + q + "?"            
                      
            # sentence2 =  s + v + obj + q + "?"
            # sentence3 = "តើ" + v +obj + q + prep + s + "?"
            # sentence4 = "តើ" + s + v + obj + q + "?"
            # sentence5 = "ចង់សួរថាតើ" + v +obj + q + prep + s + "?"
            # sentence6 = "ចង់សួរថាតើ" + s + v + obj + q + "?"
            # sentence7 = "ចង់សួរអូនឯងថាតើ" + v +obj + q + prep + s + "?"
            # sentence8 = "ចង់សួរអូនឯងថាតើ" + s + v + obj + q + "?"
            # sentence9 = "ចង់សួរអាក្អូនឯងថាតើ" + v +obj + q + prep + s + "?"
            # sentence10 = "ចង់សួរអាក្អូនឯងថាតើ" + s + v + obj + q + "?"
            # sentence11 = "ហេសួរមួយ" + v +obj + q + prep + s + "?"
            # sentence12 = "ហេសួរមួយ"  + s + v + obj + q + "?"
            # sentence13 = "ហេសួរមួយថា" + v +obj + q + prep + s + "?"
            # sentence14 = "ហេសួរមួយថា" + s + v + obj + q + "?"
            writer.writerow([sentence1])
            # writer.writerow([sentence2])
            # writer.writerow([sentence3])
            # writer.writerow([sentence4])
            writer.writerow([sentence5])
            # writer.writerow([sentence3])
            # writer.writerow([sentence4])
            # writer.writerow([sentence5])
            # writer.writerow([sentence6])
            # writer.writerow([sentence7])
            # writer.writerow([sentence8])
            # writer.writerow([sentence9])
            # writer.writerow([sentence10])
            # writer.writerow([sentence11])
            # writer.writerow([sentence12])
            # writer.writerow([sentence13])
            # writer.writerow([sentence14])
  f.close()

write_to_csv()

# %% [markdown]
# ### 7. AskAboutTopManagementPersonal

# %%
import csv

subject = [
]

verb = [
    "មាន"
]
adjective = [
    "ថ្មី",
    "ថ្មីៗ",
]

subject1 = [
    "លោកបណ្ឌិតសេងសុភាព",
    "បណ្ឌិតសេងសុភាព",
    "លោកសេងសុភាព",
    "ឯកឧត្តមសេងសុភាព",
    "លោកសំបឿន",
    "លោកហ៊ានសំបឿន",
    "ឯកឧត្តមសំបឿន",
    "ឯកឧត្តមហ៊ានសំបឿន",
]
object1 = [
    "ប្រវត្តិ",
    "ប្រវត្តិសិក្សា",
    "ប្រវត្តិការសិក្សា",
    "ប្រវត្តិជីវិត",
    "ជីវប្រវត្តិ",
    "ប្រវត្តិ",
    "ភាពជោគជ័យ",
]
question_desc = [
    "ចូររៀបរាប់",
    "ចូរប្រាប់ពី",
    "អាចនិយាយពី",
    "អាចដឹងពី",
]
subject2 = [
    "អ្នកគ្រប់គ្រង",
    "អ្នកមើលការ",
    "អ្នកមើលការខុសត្រូវ",
    "អ្នកទទួលខុសត្រូវ",
    "អ្នកទទួលបន្ទុក",
    "អ្នករ៉ាប់រង",
]
object2 = [
    "ថ្នាក់មូលដ្ឋាន",

    "computer science",
    "វិទ្យាសាស្រ្តកុំព្យូទ័រ",
    "កុំព្យូទ័រសាយអេន",

    "e-commerce"
    "ពាណិជ្ជកម្មអេឡិចត្រូនិច",
    "អុីខមមើស",

    "Telecoms and Networking",
    "Telecoms",
    "Networking",
    "Network",
    "ទូរគមនាគមន៍និងបណ្តាញ",
    "ទូរគមនាគមន៍",
    "បណ្តាញ",
    "តេឡេខម",
    "ណេតវើក",
    "ណេតវើកកីង",
]
question_human = [
    "នរណាជា",
    "អ្នកណាជា",
]

preposition = [
    "ខាង",
    "នៅ",
    "ក្នុង",
]


def write_to_csv():
    # open the file in the write mode
    f = open('6.AskAboutTopManagementPersonal.csv', 'w', encoding="utf-8")

    # create the csv writer
    writer = csv.writer(f)

    # write a generated sentences to the csv file
    for obj1 in object1:
        for s1 in subject1:
            for q_d in question_desc:
                for obj2 in object2:
                    for s2 in subject2:
                        for q_h in question_human:
                            for prep in preposition:
                            # ចូរប្រាប់ពីប្រវត្តរបស់លោកបណ្ឌិតសេងសុភាព
                            # តើនរណាជាអ្នកគ្រប់គ្រងថ្នាក់មូលដ្ឋាន
                                sentence1 = q_d+ obj1 + "របស់" +s1 + "?"
                                sentence2 = q_d+ obj1 + "របស់" +s1 + "ដែរឫទេ"+"?"
                                sentence3 = q_h + s2 + obj2 + "?"
                                sentence3 = q_h + s2 + prep +obj2 + "?"
                                sentence3 = s2 + prep +obj2 +q_h+ "?"
                                writer.writerow([sentence1])
                                writer.writerow([sentence2])
                                writer.writerow([sentence3])
    f.close()


write_to_csv()
